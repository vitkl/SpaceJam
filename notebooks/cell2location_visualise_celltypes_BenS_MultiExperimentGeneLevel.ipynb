# %%
import sys,os
import pickle
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scanpy as sc
from IPython.display import Image
data_type = 'float32'
#os.environ["THEANO_FLAGS"] = 'device=cuda,floatX=' + data_type + ',force_device=True' + ',dnn.enabled=True'
sys.path.insert(1, '/nfs/team205/vk7/sanger_projects/BayraktarLab/cell2location/')
import cell2location
import skimage.io

# %% [raw]
# data_dir = '/lustre/scratch117/cellgen/team283/Kidney-Nanostring/'
# hires = skimage.io.imread(f'{data_dir}high_res_scans/disease3_scan_CD45.tiff', True)
# img = skimage.io.imread(f'{data_dir}ROI reports/disease3_scan.png', True)
# # what is the resize factor?
# np.array(img.shape) / np.array(hires.shape)

# %%
data_dir = '/lustre/scratch117/cellgen/team283/Kidney-Nanostring/'
analysis_name = 'resultsLocationModelWTAMultiExperimentGeneLevel_7experiments_33clusters_231locations_9551genes'
adata_wta = sc.read_h5ad(f'{data_dir}{analysis_name}/sp.h5ad')

# add coordinates
adata_wta.obsm['spatial'] = adata_wta.obs[['ROICoordinateX', 'ROICoordinateY']].values

# %% [raw]
# # read images
# adata_wta.uns['spatial'] = {}
# for s in adata_wta.obs['SlideName'].unique():
#     img = skimage.io.imread(f'{data_dir}ROI reports/{s}_scan.png', True)
#
#     adata_wta.uns['spatial'][s] = {
#         'images': {'hires': img},
#         'metadata': {'chemistry_description': "Nanostring WTA",
#                      'software_version': 'NA'},
#         'scalefactors': {'fiducial_diameter_fullres': 500,
#                          'spot_diameter_fullres': 500,
#                          'tissue_hires_scalef': np.mean(np.array(img.shape) / np.array(hires.shape)),
#                          'tissue_lowres_scalef': 1}
#     }

# %% [raw]
# adata_wta.obsm['spatial'][:, 1] = -adata_wta.obsm['spatial'][:, 1]

# %% [raw]
# adata = sc.read_h5ad('/nfs/team205/vk7/sanger_projects/cell2location_paper/notebooks/selected_results/lymph_nodes_analysis/LocationModelAutoAlphaBackgroundLinearDependentWMultiExperimentLocationBackgroundNormGeneAlpha_1experiments_34clusters_4039locations_10241genes_revision_alpha200/sp.h5ad')

# %% [raw]
# adata.uns['spatial']

# %% [raw]
# adata.uns['spatial']['V1_Human_Lymph_Node']['images']['hires'].shape

# %%
# defining useful function
def select_slide(adata, s, s_col='SlideName'):
    r""" Select data for one slide from the spatial anndata object.

    :param adata: Anndata object with multiple spatial samples
    :param s: name of selected sample
    :param s_col: column in adata.obs listing sample name for each location
    """

    slide = adata[adata.obs[s_col].isin([s]), :]
    s_keys = list(slide.uns['spatial'].keys())
    s_spatial = np.array(s_keys)[[s in k for k in s_keys]][0]

    slide.uns['spatial'] = {s_spatial: slide.uns['spatial'][s_spatial]}

    return slide

# %%
adata_wta.obs['SlideName'].value_counts()
# Out:
# disease3     59
# normal3      55
# disease1B    24
# disease2B    24
# disease4     24
# normal4      23
# normal2B     22
# Name: SlideName, dtype: int64

# %%
adata_wta
# Out:
# AnnData object with n_obs × n_vars = 231 × 18503
#     obs: 'SlideName', 'ScanName', 'ROILabel', 'SegmentLabel', 'SegmentDisplayName', 'Sample_ID', 'AOISurfaceArea', 'AOINucleiCount', 'ROICoordinateX', 'ROICoordinateY', 'RawReads', 'TrimmedReads', 'StitchedReads', 'AlignedReads', 'DeduplicatedReads', 'SequencingSaturation', 'UMIQ30', 'RTSQ30', 'disease_status', 'pathology', 'region', 'LOQ', 'NormalizationFactor', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'mean_spot_factorsAscending vasa recta endothelium', 'mean_spot_factorsB cell', 'mean_spot_factorsCD4 T cell', 'mean_spot_factorsCD8 T cell', 'mean_spot_factorsConnecting tubule', 'mean_spot_factorsDescending vasa recta endothelium', 'mean_spot_factorsDistinct proximal tubule 1', 'mean_spot_factorsDistinct proximal tubule 2', 'mean_spot_factorsEpithelial progenitor cell', 'mean_spot_factorsFibroblast', 'mean_spot_factorsGlomerular endothelium', 'mean_spot_factorsIndistinct intercalated cell', 'mean_spot_factorsMNP-a/classical monocyte derived', 'mean_spot_factorsMNP-b/non-classical monocyte derived', 'mean_spot_factorsMNP-c/dendritic cell', 'mean_spot_factorsMNP-d/Tissue macrophage', 'mean_spot_factorsMast cell', 'mean_spot_factorsMyofibroblast', 'mean_spot_factorsNK cell', 'mean_spot_factorsNKT cell', 'mean_spot_factorsNeutrophil', 'mean_spot_factorsPelvic epithelium', 'mean_spot_factorsPeritubular capillary endothelium 1', 'mean_spot_factorsPeritubular capillary endothelium 2', 'mean_spot_factorsPlasmacytoid dendritic cell', 'mean_spot_factorsPodocyte', 'mean_spot_factorsPrincipal cell', 'mean_spot_factorsProliferating Proximal Tubule', 'mean_spot_factorsProximal tubule', 'mean_spot_factorsThick ascending limb of Loop of Henle', 'mean_spot_factorsTransitional urothelium', 'mean_spot_factorsType A intercalated cell', 'mean_spot_factorsType B intercalated cell', 'sd_spot_factorsAscending vasa recta endothelium', 'sd_spot_factorsB cell', 'sd_spot_factorsCD4 T cell', 'sd_spot_factorsCD8 T cell', 'sd_spot_factorsConnecting tubule', 'sd_spot_factorsDescending vasa recta endothelium', 'sd_spot_factorsDistinct proximal tubule 1', 'sd_spot_factorsDistinct proximal tubule 2', 'sd_spot_factorsEpithelial progenitor cell', 'sd_spot_factorsFibroblast', 'sd_spot_factorsGlomerular endothelium', 'sd_spot_factorsIndistinct intercalated cell', 'sd_spot_factorsMNP-a/classical monocyte derived', 'sd_spot_factorsMNP-b/non-classical monocyte derived', 'sd_spot_factorsMNP-c/dendritic cell', 'sd_spot_factorsMNP-d/Tissue macrophage', 'sd_spot_factorsMast cell', 'sd_spot_factorsMyofibroblast', 'sd_spot_factorsNK cell', 'sd_spot_factorsNKT cell', 'sd_spot_factorsNeutrophil', 'sd_spot_factorsPelvic epithelium', 'sd_spot_factorsPeritubular capillary endothelium 1', 'sd_spot_factorsPeritubular capillary endothelium 2', 'sd_spot_factorsPlasmacytoid dendritic cell', 'sd_spot_factorsPodocyte', 'sd_spot_factorsPrincipal cell', 'sd_spot_factorsProliferating Proximal Tubule', 'sd_spot_factorsProximal tubule', 'sd_spot_factorsThick ascending limb of Loop of Henle', 'sd_spot_factorsTransitional urothelium', 'sd_spot_factorsType A intercalated cell', 'sd_spot_factorsType B intercalated cell', 'q05_spot_factorsAscending vasa recta endothelium', 'q05_spot_factorsB cell', 'q05_spot_factorsCD4 T cell', 'q05_spot_factorsCD8 T cell', 'q05_spot_factorsConnecting tubule', 'q05_spot_factorsDescending vasa recta endothelium', 'q05_spot_factorsDistinct proximal tubule 1', 'q05_spot_factorsDistinct proximal tubule 2', 'q05_spot_factorsEpithelial progenitor cell', 'q05_spot_factorsFibroblast', 'q05_spot_factorsGlomerular endothelium', 'q05_spot_factorsIndistinct intercalated cell', 'q05_spot_factorsMNP-a/classical monocyte derived', 'q05_spot_factorsMNP-b/non-classical monocyte derived', 'q05_spot_factorsMNP-c/dendritic cell', 'q05_spot_factorsMNP-d/Tissue macrophage', 'q05_spot_factorsMast cell', 'q05_spot_factorsMyofibroblast', 'q05_spot_factorsNK cell', 'q05_spot_factorsNKT cell', 'q05_spot_factorsNeutrophil', 'q05_spot_factorsPelvic epithel ...
#     var: 'TargetName', 'ProbeID', 'Negative'
#     uns: 'mod'
#     obsm: 'negProbes', 'spatial'

# %%
adata_wta.obs['AOISurfaceArea']
# Out:
# 0       22152.10924
# 1       71817.92407
# 2       37316.69780
# 3      102112.72680
# 4       18398.68515
#            ...
# 226     34871.37949
# 227     29638.49826
# 228     24203.53455
# 229     24850.07060
# 230     22985.60386
# Name: AOISurfaceArea, Length: 231, dtype: float64

# %% [raw]
# sel_clust = adata_wta.uns['mod']['fact_names']
# sel_clust_col = ['q05_spot_factors' + str(i) for i in sel_clust]
#
# # select one section correctly subsetting histology image data
# slide = select_slide(adata_wta, 'normal3', s_col='SlideName')
# #slide = adata_wta[adata_wta.obs['SlideName'] == 'normal3',:].copy()
#
# # plot with nice names
# with mpl.rc_context({'figure.figsize': (7, 10), "font.size": 18}):
#     # add slide.obs with nice names
#     slide.obs[sel_clust] = slide.obs[sel_clust_col]
#
#     sc.pl.spatial(slide, cmap='magma',
#                   color=sel_clust[0:4], # limit size in this notebook
#                   ncols=5,
#                   spot_size=1000, #img_key='hires',
#                   #alpha_img=0.9,
#                   vmin=0, vmax='p99.2'
#                  )

# %%
sel_clust = adata_wta.uns['mod']['fact_names']
sel_clust_col = ['q05_spot_factors' + str(i) for i in sel_clust]

# select one section correctly subsetting histology image data
#slide = select_slide(adata_wta, 'normal3', s_col='SlideName')
slide = adata_wta[adata_wta.obs['SlideName'] == 'normal3',:].copy()

# plot with nice names
with mpl.rc_context({'figure.figsize': (7, 10), "font.size": 18}):
    # add slide.obs with nice names
    slide.obs[sel_clust] = (slide.obs[sel_clust_col].T / (slide.obs['AOISurfaceArea'] / (10**6))).T

    sc.pl.spatial(slide, cmap='magma',
                  color=sel_clust, # limit size in this notebook
                  ncols=5,
                  spot_size=1000, img_key=None,
                  #alpha_img=0.9,
                  vmin=0, vmax='p99.2'
                 )

# %%
sel_clust = adata_wta.uns['mod']['fact_names']
sel_clust_col = ['q05_spot_factors' + str(i) for i in sel_clust]
sel_clust_new = ['q05_cell_density_per_mm2_' + str(i) for i in sel_clust]

adata_wta.obs[sel_clust_new] = (adata_wta.obs[sel_clust_col].T / (adata_wta.obs['AOISurfaceArea'] / (10**6))).T

# %%
adata_wta.obs[sel_clust_new].to_csv(f'{data_dir}{analysis_name}/q05_cell_density_per_mm2.csv')
f'{data_dir}{analysis_name}/q05_cell_density_per_mm2.csv'
# Out:
# '/lustre/scratch117/cellgen/team283/Kidney-Nanostring/resultsLocationModelWTAMultiExperimentGeneLevel_7experiments_33clusters_231locations_9551genes/q05_cell_density_per_mm2.csv'

# %%
def plot_spatial_per_cell_type(adata, 
                               cell_type=adata_wta.uns['mod']['fact_names'][0],
                               samples=adata_wta.obs['SlideName'].unique(),
                              ncol=4):
    n_samples = len(samples)
    nrow = int(np.ceil(n_samples / ncol))
    fig, axs = plt.subplots(nrow, ncol, figsize=(28, 6))
    if nrow == 1:
        axs = axs.reshape((1, ncol))
    
    col_name = f'q05_cell_density_per_mm2_{cell_type}'
    vmax = np.quantile(adata.obs[col_name].values, 0.992)
    adata.obs[cell_type] = adata.obs[col_name].copy()
    
    from itertools import chain
    ind = list(chain(*[[(i, j) for i in range(nrow)] for j in range(ncol)]))
    
    for i, s in enumerate(samples):
        #sp_data_s = select_slide(adata, s, s_col='SlideName')
        sp_data_s = adata[adata.obs['SlideName'] == s,:].copy()
        sc.pl.spatial(sp_data_s, cmap='magma',
                      color=cell_type, 
                      spot_size=1000, img_key=None,
                      vmin=0, vmax=vmax, ax=axs[ind[i][0],ind[i][1]], show=False
                                            )
        axs[ind[i][0],ind[i][1]].title.set_text(cell_type+'\n'+s)
    
    if len(samples) < len(axs.flatten()):
        for i in range(len(samples), len(axs.flatten())):
            axs[ind[i][0],ind[i][1]].axis('off')
    
    fig.tight_layout(pad=0.5)
        
    return fig

# %%
for c in adata_wta.uns['mod']['fact_names']:
    fig = plot_spatial_per_cell_type(adata_wta, cell_type=c)
    from re import sub
    c = sub(' ', '_', c)
    c = sub('/', '_', c)
    fig.savefig(f"{data_dir}{analysis_name}/plots/spatial/per_cell_type/W_cell_density_per_mm2_{c}.png",
                bbox_inches='tight')
    if c == adata_wta.uns['mod']['fact_names'][5]:
        fig.show()
    fig.clear()
    plt.close(fig)

f"{data_dir}{analysis_name}/plots/spatial/per_cell_type/"
# Out:
# '/lustre/scratch117/cellgen/team283/Kidney-Nanostring/resultsLocationModelWTAMultiExperimentGeneLevel_7experiments_33clusters_231locations_9551genes/plots/spatial/per_cell_type/'

# %% [markdown]
# ## Plot violins/boxplots plot per condition

# %%
adata_wta.obs['region_original'] = adata_wta.obs['region'].copy()
adata_wta.obs['SegmentLabel_aux'] = adata_wta.obs['SegmentLabel'].astype(str).copy()
adata_wta.obs.loc[adata_wta.obs['region_original'] == 'glomerulus', 'SegmentLabel_aux'] = ''
adata_wta.obs['region'] = adata_wta.obs['region'].astype(str) \
+ '_'+ adata_wta.obs['SegmentLabel_aux'].astype(str)
adata_wta.obs[['disease_status', 'pathology', 'region']].value_counts()
# Out:
# disease_status  pathology  region
# DKD             abnormal   glomerulus_     65
# normal          healthy    glomerulus_     54
# DKD             nan        tubule_PanCK    24
#                            tubule_neg      24
#                 healthy    glomerulus_     18
# normal          nan        tubule_PanCK    17
#                            tubule_neg      17
#                 abnormal   glomerulus_     12
# dtype: int64

# %%
def plot_violins(obs=adata_wta.obs, plot_type='violin',
                 cell_types=adata_wta.uns['mod']['fact_names'],
                 x="region", hue="disease_status", ncol=6):
    n_cell_types = len(cell_types)
    nrow = int(np.ceil(n_cell_types / ncol))
    fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))
    if nrow == 1:
        axs = axs.reshape((1, ncol))
        
    from itertools import chain
    ind = list(chain(*[[(i, j) for i in range(nrow)] for j in range(ncol)]))
    
    for i, cell_type in enumerate(cell_types):
        col_name = f'q05_cell_density_per_mm2_{cell_type}'
        
        if plot_type=='violin':
            sns.violinplot(data=adata_wta.obs, x=x, y=col_name, hue=hue,
                        split=True, inner="quart", 
                        linewidth=1,
                        palette={"normal": ".5", "DKD": ".85"},
                        ax=axs[ind[i][0],ind[i][1]])
            axs[ind[i][0],ind[i][1]].set_ylim(0);
            #sns.swarmplot(data=adata_wta.obs, x=x, y=col_name, hue=hue,
            #              palette={"normal": ".0", "DKD": ".0"}, 
            #              dodge=True, size=3,
            #              ax=axs[ind[i][0],ind[i][1]])
            
        if plot_type=='boxplot':
            sns.boxplot(data=adata_wta.obs, x=x, y=col_name, hue=hue,
                        linewidth=1,
                        palette={"normal": ".5", "DKD": ".85"},
                        ax=axs[ind[i][0],ind[i][1]])
            #sns.swarmplot(data=adata_wta.obs, x=x, y=col_name, hue=hue,
            #              palette={"normal": ".0", "DKD": ".0"}, 
            #              dodge=True, size=3,
            #              ax=axs[ind[i][0],ind[i][1]])
            
        sns.despine(left=True);

        axs[ind[i][0],ind[i][1]].title.set_text(cell_type)
    
    if len(cell_types) < len(axs.flatten()):
        for i in range(len(cell_types), len(axs.flatten())):
            axs[ind[i][0],ind[i][1]].axis('off')
    
    fig.tight_layout(pad=0.5)
        
    return fig

# %%
adata_wta.obs[f"q05_cell_density_per_mm2_{adata_wta.uns['mod']['fact_names'][0]}"].min()
# Out:
# 0.0011882716873561606

# %%
plot_violins(obs=adata_wta.obs, 
                 cell_types=adata_wta.uns['mod']['fact_names'],
                 x="region", hue="disease_status", ncol=6);

# %%
plot_violins(obs=adata_wta.obs, plot_type='boxplot',
                 cell_types=adata_wta.uns['mod']['fact_names'],
                 x="region", hue="disease_status", ncol=6);
